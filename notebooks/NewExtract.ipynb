# %%
# %load_ext autoreload
# %autoreload 2

# %%
from css_proj.preprocess.cure_data import get_tweet_info, get_empty_df_cure, get_df_cure, clean_up_intermediate
from css_proj.preprocess.utils import initialize_api

# %%
api = initialize_api()

# %%
# %cd ../
# Out:
# /home/harshapk/Projects/CSS_Project

# %%
df = get_empty_df_cure()
df.head()
# Out:
#               tweet_id  label  state  \
# 0  1238288071050706944      0      1
# 1  1243032337924972546      0      1
# 2  1236722713424801798      0      1
# 3  1231359858894606336      0     -1
# 4  1248464260646068224      0     -1
#
#                                           tweet_text  retweets  likes  \
# 0  People who drink Arrowhead water on a daily ba...         0      8
# 1  people who drink tin sausage water are immune ...         1      1
# 2  People who drink water out of the water hose a...         0      0
# 3                                                            0      0
# 4                                                            0      0
#
#                      created lang               device             user_id  \
# 0  2020-03-13 02:17:37+00:00   en   Twitter for iPhone            43567150
# 1  2020-03-26 04:29:38+00:00   en      Twitter Web App            66214451
# 2  2020-03-08 18:37:26+00:00   en  Twitter for Android  749253101262024704
# ...

# %%
df = get_df_cure(api, start_idx=0)
# Out:
#  75%|███████▌  | 1803/2400 [00:01<00:00, 1338.46it/s]
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
#  78%|███████▊  | 1876/2400 [00:12<00:11, 47.37it/s]
# 404 Not Found
# 144 - No status found with that ID.
#  78%|███████▊  | 1877/2400 [00:13<00:11, 46.48it/s]
# 404 Not Found
# ...

# %%
df.iloc[900:930]
# Out:
#                 tweet_id  label  state  \
# 900  1262758662331748353      1     -1
# 901  1239860966868652032      1      1
# 902  1262659145641025536      1      1
# 903  1253382462434091009      1      1
# 904  1239943437895512066      1     -1
# 905  1238386024000167936      1      1
# 906  1248692639735709696      1      1
# 907  1249851162477633537      1      1
# 908  1238400415709802497      1      1
# 909  1235078378811731971      1      1
# 910  1253901218419806209      1      1
# 911  1238636960702332928      1      1
# 912  1247745180825825282      1      1
# 913  1239220144842215425      1     -1
# 914  1242440586348683266      1      1
# 915  1238886023305867266      1      1
# 916  1238833646326276096      1      1
# 917  1247460662994800643      1      1
# 918  1243446899220324352      1      1
# 919  1254789947308953602      1      1
# 920  1244505960917258240      1      1
# 921  1239404120827547648      1     -1
# 922  1239958658353713158      1      1
# ...

# %%
df = clean_up_intermediate()

# %%
df
# Out:
#                  tweet_id  label  \
# 0     1238288071050706944      0
# 1     1243032337924972546      0
# 2     1236722713424801798      0
# 6     1224966508004200448      0
# 7     1242478018968330240      0
# ...                   ...    ...
# 2395  1250587339979554816      2
# 2396  1243830544292614145      2
# 2397  1225659619927703558      2
# 2398  1233295519461429249      2
# 2399  1231869742090199042      2
#
#                                              tweet_text  retweets  likes  \
# 0     People who drink Arrowhead water on a daily ba...         0      8
# 1     people who drink tin sausage water are immune ...         1      1
# 2     People who drink water out of the water hose a...         0      0
# 6     Claim: novel #coronavirus can be cured overnig...         5      3
# 7     People who drink water from the sink are immun...         0      5
# ...                                                 ...       ...    ...
# ...
