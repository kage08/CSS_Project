# %%
# %load_ext autoreload
# %autoreload 2
# %cd ../
# Out:
# /home/harshapk/Projects/CSS_Project

# %%
from css_proj.preprocess.covid_lies import get_empty_df_lies, get_df_lies, clean_up_intermediate
from css_proj.preprocess.utils import initialize_api

# %%
api = initialize_api()

# %%
df = get_empty_df_lies()
df.head()
# Out:
#   misconception_id                                      misconception  \
# 0                              Coronavirus is genetically engineered.
# 1                   Blowing conch shells destroys coronavirus pote...
# 2                   Swans and dolphins swimming in Venice canals f...
# 3                                          Cocaine cures coronavirus.
# 4                   Observing janata curfew will result in the red...
#
#               tweet_id label  state  \
# 0  1233965490948591616    na     -1
# 1  1233907923765559296    na      1
# 2  1233911842910720000    na      1
# 3  1233947734094290944    na      1
# 4  1233937085297332224    na     -1
#
#                                           tweet_text  retweets  likes  \
# 0                                                            0      0
# 1  Getting coronavirus and then coughing on peopl...         1      0
# 2  @Barioth_a_bot そう…ですね…私は常時深海に居ります故…ふわふわ、という感触で...         0      0
# ...

# %%
df = get_df_lies(api, start_idx=0)
# Out:
#  96%|█████████▌| 6312/6591 [00:03<00:00, 2154.86it/s]
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# ...

# %%
df = clean_up_intermediate()

# %%
df
# Out:
#      misconception_id                                      misconception  \
# 1                      Blowing conch shells destroys coronavirus pote...
# 2                      Swans and dolphins swimming in Venice canals f...
# 3                                             Cocaine cures coronavirus.
# 9                      It is safe for individuals infected with COVID...
# 13                     Observing janata curfew will result in the red...
# ...               ...                                                ...
# 6583                                    Chloroquine can cure coronavirus
# 6586                   It is safe for individuals infected with COVID...
# 6587                                        Vitamin C cures coronavirus.
# 6589                   Lions were freed to keep people off the street...
# 6590                   Holy communion cannot be the cause of the spre...
#
#                  tweet_id label  \
# 1     1233907923765559296    na
# ...
